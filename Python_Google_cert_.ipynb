# %% [markdown]
# <a href="https://colab.research.google.com/github/krunchkrew123/Python_Learning/blob/main/Python_Google_cert_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Print Hello Python
print("Hello Python!")
# Out:
# Hello Python!

# %%
# calculate numbers with print
print(1+1)
# Out:
# 2

# %%
# Determine boolean values
print(10<5)
print(9<12)
# Out:
# False
# True

# %%
# Print a list
print(["dtanaka", "mabadi", "aestrada"])
# Out:
# ['dtanaka', 'mabadi', 'aestrada']

# %%
# Use a variable to store device id
device_id = "h32rb17"
print(device_id)
print("m50pi31")
# Out:
# h32rb17
# m50pi31

# %%
# Use a type function
device_id = "h32rb17"
data_type = type(device_id)
print(data_type)
# Out:
# <class 'str'>

# %%
# Demonstrate a type error
device_id = "h32rb17"
number = 3
print(device_id + number)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_12023/1522262556.py in <cell line: 0>()
#       2 device_id = "h32rb17"
#       3 number = 3
# ----> 4 print(device_id + number)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Reassign a variable
device_id = "h32rb17"
print(device_id)
device_id = "n73ab07"
print(device_id)
# Out:
# h32rb17
# n73ab07

# %%
# assign username
username = 'nzhao'
old_username = username
username = 'nzhao2'
print("previous username:", old_username)
print("Current username:", username)
# Out:
# previous username: nzhao
# Current username: nzhao2

# %%
# Assign device id
device_id = '72e08x0'
# display device id
print(device_id)
# device id type
device_id_type = type(device_id)
# display device id
print(device_id_type)
# Out:
# 72e08x0
# <class 'str'>

# %%
# Assign username list
username_list = 'madebowa', 'jnguyen', 'tbecker', 'nhersh', 'redwards'
# display username list
print('Allowed Users:', username_list)
username_list_type = type(username_list)
print(username_list_type)
# updated user list
old_username_list = username_list
username_list = 'madebowa', 'jnguyen', 'tbecker', 'nhersh', 'redwards', 'lpope'
print("Old username list:", old_username_list)
print('Updated User list', username_list)
# Out:
# Allowed Users: ('madebowa', 'jnguyen', 'tbecker', 'nhersh', 'redwards')
# <class 'tuple'>
# Old username list: ('madebowa', 'jnguyen', 'tbecker', 'nhersh', 'redwards')
# Updated User list ('madebowa', 'jnguyen', 'tbecker', 'nhersh', 'redwards', 'lpope')

# %%
# max logins = 3
max_logins = 3
max_logins_type = type(max_logins)
print(max_logins_type)
print('The Max Number of logins is', max_logins)
# login attempts
login_attempts = 6
login_attempts_type = type(login_attempts)
print('Number of logins:', login_attempts)
print('Data Type:', login_attempts_type)
print(login_attempts <= max_logins)
# Assign login status a boolean value of false
login_status = False
login_status_type = type(login_status)
print('Logged in', login_status)
print(login_status_type)
# Out:
# <class 'int'>
# The Max Number of logins is 3
# Number of logins: 6
# Data Type: <class 'int'>
# False
# Logged in False
# <class 'bool'>

# %%
# create a conditional
operating_system = "os 2"
if operating_system == "os 2":
   print("updates needed")
# add an elsde statement
operating_system = "os 3"
if operating_system == "os 2":
   print("updates needed")
else:
     print('No updates needed')
# Out:
# updates needed
# No updates needed

# %%
# assign variable named system different values
system = "os 4"
#if os 2 is running display no updates needed
if system == 'os 2':
  print('No updates needed')
elif system == 'os 1' or system == 'os 3':
  print('Update needed')
else:
  print('See Technician')
# Out:
# See Technician

# %%
# assign approved users to usernames of approved users
approved_user1 = 'elarson'
approved_user2 = 'bmoreno'
# assign username of the specific user trying to login
username = 'bmoreno'
# if user is among the approved users then display message that they are approved
#otherwise display that they dont have access
if username == approved_user1 or approved_user2:
  print('Access Granted')
else:
    print('Access Denied')
# Out:
# Access Granted

# %%
# assign an approved user list
approved_list = ['elarson', 'bmoreno', 'tshah', 'sgilmore', 'eraab']
#assign username to specific user trying to log in
username = 'bmoreno'
# if user is among the approved users then access granted
#otherwise access denied
if username in approved_list:
  print('Access Granted')
else:
    print('Access Denied')
# assign a boolean value to organization hours that represents the user trying to login during business hours
organization_hours = True
# if the entered organization hours equals true then display 'login attempt made during organization hours'
# otherwise display 'login attempt made outside of organization hours'
if organization_hours == True:
  print('Login attempt made during organization hours')
else:
  print('Login attempt made outside of organization hours')
# if the user is among the approved users and they are logging in during business hours display that the user is logged in
# otherwise, convey that either the username is not approved or the login attempt was made outside of organization hours
if username in approved_list and organization_hours == True:
  print('Login attempt made by an approved user during organization hours')
else:
  print('Username not approved or login attempt made outside of organization hours')
# Out:
# Access Granted
# Login attempt made during organization hours
# Login attempt made by an approved user during organization hours

# %%
# run a for loop with range
for i in range(10):
  print('Cannot connect to the destination.')

# %%
# create a while loop
max_devices = 5
i = 1

while i < max_devices:
  print('User can still connect additional devices')
  i= i + 1
print('User has reached maximum number of connected devices')
# Out:
# User can still connect additional devices
# User can still connect additional devices
# User can still connect additional devices
# User can still connect additional devices
# User has reached maximum number of connected devices

# %%
for i in range(0, 5, 1):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# iterative statement using for, range and a loop variable of i
# display connection could not be established 3 times
i = 0
for i in range(3):
  print('Connection could not be established')
# Out:
# Connection could not be established
# Connection could not be established
# Connection could not be established

# %%
# create a variable called connection_attempts that stores the number of times a user has tried to connect to the network
connection_attempts = 7
# iterative statement using for range a loop variable of i and coonection_attempts
# display connection could not be established as many times as specified by connection attempts
for i in range(connection_attempts):
  print('Connection could not be established')
# Out:
# Connection could not be established
# Connection could not be established
# Connection could not be established
# Connection could not be established
# Connection could not be established
# Connection could not be established
# Connection could not be established

# %%
# assign ip_addresses to a list of ip addresses from which users have tried to login
ip_addresses = ['192.168.142.245', '192.168.109.50', '192.168.86.232', '192.168.131.147', '192.168.205.12', '192.168.200.48']
# for loop that displays the elements of ip addresses one at a time
i = ip_addresses
for i in ip_addresses:
  print(i)
# Out:
# 192.168.142.245
# 192.168.109.50
# 192.168.86.232
# 192.168.131.147
# 192.168.205.12
# 192.168.200.48

# %%
# Assign 'allow_list' to a alist of ip addresses that are aloud to login
allow_list = ['192.168.243.140', '192.168.109.50', '192.168.151.162', '192.168.178.71', '192.168.86.232', '192.168.3.24', '192.168.170.243', '192.168.119.173']

# assign 'ip_addresses' to a list of ip addresses from which users have tried to login
ip_addresses = ['192.168.142.245', '192.168.109.50', '192.168.56.232', '192.168.131.147', '192.168.205.12', '192.168.200.48']

# for each ip address in the list of ip addresses from which users have tried to login,
# if it is among the allowed addresses then display "ip address allowed"
# otherwise display "ip address is not allowed"
i = ip_addresses
for i in ip_addresses:
  if i in allow_list:
    print('Ip address is allowed')
  else:
    print('Ip address is not allowed')
# Out:
# Ip address is not allowed
# Ip address is allowed
# Ip address is not allowed
# Ip address is not allowed
# Ip address is not allowed
# Ip address is not allowed

# %%
# Assign a loop variable i to be an initial value of 5000
i = 5000
# while loop that generates unique employee IDs for the sales department by iterating through numbers
# and displays each id created
# this loop displays 'only 10 valid employee ids remaining' once i reaches 5100
while i <= 5150:
  print(i)
  if i == 5100:
    print('Only 10 valid employee IDs remaining')
  i += 5
# Out:
# 5000
# 5005
# 5010
# 5015
# 5020
# 5025
# 5030
# 5035
# 5040
# 5045
# 5050
# 5055
# 5060
# 5065
# 5070
# 5075
# 5080
# 5085
# 5090
# 5095
# 5100
# Only 10 valid employee IDs remaining
# 5105
# 5110
# 5115
# 5120
# 5125
# 5130
# 5135
# 5140
# 5145
# 5150

# %%
# define a function
def greet_employee():
  print('Welcome! You are logged in.')

#call a function
greet_employee()
# Out:
# Welcome! You are logged in.

# %%
# define a function named alert
def alert():
  for i in range(3):
    print('Potential security issue. Investigate further.')

# call the alert function
alert()
# Out:
# Potential security issue. Investigate further.
# Potential security issue. Investigate further.
# Potential security issue. Investigate further.

# %%
# define a function named 'list_to_string()'
def list_to_string():
  # store the list of approved usernames in a variable named 'username_list'
  username_list = ['elarson', 'bmoreno', 'tshah', 'eraab', 'gesperza', 'alevitsk', 'wjaffrey']
  # Assign sum_variable to an empty string
  sum_variable = ''
  # write a loop that iterates through the elements of username_list and
  # displays each element
  for i in username_list:
    sum_variable = sum_variable + i + ','
  # display the value of sum_variable
  print(sum_variable)
# call the list_to_string function
list_to_string()
# Out:
# elarson,bmoreno,tshah,eraab,gesperza,alevitsk,wjaffrey,

# %%
# greet employees by name
def greet_employee(name):
  print('Welcome! You are logged in', name)
greet_employee('Charlie Patel')
# Out:
# Welcome! You are logged in Charlie Patel

# %%
# return information using a function
def calculate_fails(total_attempts, failed_attempts):
  fail_percentage = failed_attempts / total_attempts
  return fail_percentage
percentage = calculate_fails(4,2)
if (percentage >= .5):
  print('Account locked')
# Out:
# Account locked

# %%
# create a list of failed logins in chronological order by month
failed_login_list = [119, 101, 99, 91, 92, 105, 108, 85, 88, 90, 264, 223]

# sort the amount of failed logins low:high
print(sorted(failed_login_list))
# Out:
# [85, 88, 90, 91, 92, 99, 101, 105, 108, 119, 223, 264]

# %%
# define a function named analyze_logins that takes 3 parameters usernames & current_day_logins & average_day_logins
def analyze_logins(usernames, current_day_logins, average_day_logins):
  print('Current day login total for', usernames, 'is', current_day_logins)
  # display message about average number of logins a user has made
  print('Average logins per day for', usernames, 'is', average_day_logins)
# call analyze_logins
analyze_logins('ejones', 9, 3)
# Out:
# Current day login total for ejones is 9
# Average logins per day for ejones is 3

# %%
# convert an integer into a string
new_string = str(123)
print(type(new_string))
# Out:
# <class 'str'>

# %%
# print the length of a string hello
print(len('Hello'))
# Out:
# 5

# %%
# concatenate 2 strings
print('Hello' + 'world')
# Out:
# Helloworld

# %%
# apply the upper method the string hello
print('Hello'.upper())
# apply the lower method to the string hello
print('HELLO'.lower())
# Out:
# HELLO
# hello

# %%
# extract a slice from a string
print('Hello'[1:4])
# Out:
# ell

# %%
# use the index string method
print('HEllo'.index('E'))
# Out:
# 1

# %%
# assign employee_id to a four digit number as initial value
employee_id = 4186
# display the data type of employee_id
print(type(employee_id))
# reassign employee_id to the same value but in the form of a string
employee_id = str(employee_id)
# display the data type of employee_id now
print(type(employee_id))
# write a conditional statement that displays a message if the length of employee
# id is less than 5 digits
if len(employee_id) < 5:
  print('This employee id has less than 5 digits. It does not meet length reqirements.')
# conditional statement that updates the employee id if its length is less than 5 digits
if len(employee_id) < 5:
  employee_id = 'E' + employee_id
# display updated employee_id
print(employee_id)
# Out:
# <class 'int'>
# <class 'str'>
# This employee id has less than 5 digits. It does not meet length reqirements.
# E4186

# %%
# assign device_id to a string that contains alphanumeric characters
device_id = 'r262c36'
# extract the fourth character in device id and display it
print(device_id[4])
# extract the first through thrid characters in device_oid and display the output
print(device_id[1:4])
# Out:
# c
# 262

# %%
# assign url to a specific url
url = 'https://exampleURL1.com'
#extract the protocol of url along with the syntax following it, display the result
print(url[0:8])
# display the index where the domain extension.com is located in url
print(url.index('.com'))
# assign ind to output of applying .index to url in order to extract the starting index of .com in url
ind = url.index('.com')
# extract the domain extension in url and display it
print(url[ind:ind+4])
# extract website name from url and display it
print(url[ind-11:ind-1])
# Out:
# https://
# 19
# .com
# exampleURL

# %%
# Write an algorithm
address = '198.223.xx.xx'
#extract first 3 characters
print(address[0:3])
# ip list
IP = ['198.223.xx.xx', '198.101.xx.xx', '180.064.xx.xx', '192.168.xx.xx', '184.090.xx.xx']
#extract first 3 characters
networks =[]
for address in IP:
  networks.append(address[0:3])
print(networks)
# Out:
# 198
# ['198', '198', '180', '192', '184']

# %%
# develop an algorithm
# assign approved_users to a list of approved usernames
approved_users = ['elarson', 'bmoreno', 'tshah', 'sgilmore', 'eraab']
# assign approved_odevices to a list of device ids that correspond to the usersnames
approved_devices = ['8rp2k75', 'hl0s5o1', '2ye3lzg', '4n482ts', 'a307vir']
# display the element at the specified index in approved_users
#print(approved_users[0])
# display the element at the specified index in approved_devices
#print(approved_devices[0])
# Assign new_user to the username of a new approved user
new_user = 'gesparza'
# assign new_device to the device id of the new approved user
new_device = '3rcv4w6'
# add that users name and device id to approved_users and approved_devices
approved_users.append(new_user)
approved_devices.append(new_device)
# display the contents of approved users
#print(approved_users)
#display contents of approved devices
#print(approved_devices)
# assign removed_user to the username that has left the team
removed_user = 'tshah'
# assign removed_device to the device id of the employee that has left the team
removed_device = '2ye3lzg'
# remove  that employees username and device id from both lists
approved_users.remove(removed_user)
approved_devices.remove(removed_device)
# display approved_users
#print(approved_users)
# display approved_devices
#print(approved_devices)
# assign a username to 'username'
username = 'sgilmore'
# conditional if statement
# if username belongs to approved users then display "the user is approved"
# otherwise display "the user is not authorized to access the system
#if username in approved_users:
#  print('The user,', username, ', is authorized to access the system')
#else:
#  print('The user,', username, ', is not authorized tho access the system')
# assign ind to the index of username in approved users
ind = approved_users.index(username)
# display the value of ind
#print(ind)
# display the device id at the index that matches the value of ind in approved_users
#print(approved_devices[ind])
# assign device_id to a device id
device_id = '4n482ts'
# conditional if statement
# if username belongs to approved_users and if the device id at ind in approved devices
# then display that the user is approved
# followed by a message that the user has the right device
#if username in approved_users and approved_devices[ind] == device_id:
#  print('The username,', username, 'is approved to access the system')
#  print(device_id, 'is the assigned device for,', username)
# elif statement
# handles the case when username belongs to approved users but element at ind in approved_devices does not match device id
# and displays 2 messages accordingly
#elif approved_devices[ind] != device_id:
#  print('The user', username, 'is approved to access the system, but', device_id, 'is not their assigned device.')
# define a function named 'Login' that takes 2 parameters username and device id
# Out:
# The username, sgilmore is approved to access the system
# 4n482ts is the assigned device for, sgilmore

# %%
# full algorithm
# assign list of users to approved_users
approved_users = ['elarson', 'bmoreno', 'sgilmore', 'eraab', 'gesparza']
# assign approved devices to a list of device ids that correspond to the username
approved_devices = ['8rp2k75', 'hl0s5o1', '4n482ts', 'a307vir', '3rcv4w6']
# assign username and device id
username = 'sgilmore'
device_id = '4n482ts'
# define a function named "login" that takes 2 parameters username and device id
def Login(username, device_id):
  if username in approved_users:
    print('The user,', username, 'is approved to access the system.')
    ind = approved_users.index(username)
    if device_id == approved_devices[ind]:
      print(device_id, 'is the assigned device for', username)
    else:
      print(device_id, 'is not their assigned device')
  else:
    print("The username", username, 'is not approved to access the system')
# call the function just defined to experiment with different usernames and device ids
Login('elarson', '8rp2k75')
Login('bmoreno', '4n482ts')
Login('Tshah', '1234jfj')
# Out:
# The user, elarson is approved to access the system.
# 8rp2k75 is the assigned device for elarson
# The user, bmoreno is approved to access the system.
# 4n482ts is not their assigned device
# The username Tshah is not approved to access the system

# %%
# regex
# import the re module
import re
# assign devices to a string containing device ids each id represented by alphanumeric characters
devices = 'r262c36 67bv8fy 41j1u2e r151dm4 1270t3o 42dr56i r15xk9h 2j33krk 253be78 ac742a1 r15u9q5 zh86b2l ii286fq 9x482kt 6oa6m6u x3463ac i4l56nq g07h55q 081qc9t r159rlu'
# display contents of devices
#print(devices)
# assign a target_pattern to a regular expression pattern for finding device ids
target_pattern = 'r15\w+'
# use re.findall() to find the device ids that start with r15 and display the output
print(re.findall(target_pattern, devices))
# Out:
# ['r151dm4', 'r15xk9h', 'r15u9q5', 'r159rlu']
# <>:9: SyntaxWarning: invalid escape sequence '\w'
# <>:9: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipykernel_11639/1890595864.py:9: SyntaxWarning: invalid escape sequence '\w'
#   target_pattern = 'r15\w+'

# %%
# assing log_file to a string containing username date login time and ip address for a series of login attempts
log_file ='eraab 2022-05-10 6:03:41 192.168.152.148 \niuduike 2022-05-09 6:46:40 192.168.22.115 \nsmartell 2022-05-09 19:30:32 192.168.190.178 \narutley 2022-05-12 17:00:59 1923.1689.3.24 \nrjensen 2022-05-11 0:59:26 192.168.213.128 \naestrada 2022-05-09 19:28:12 1924.1680.27.57 \nasundra 2022-05-11 18:38:07 192.168.96.200 \ndkot 2022-05-12 10:52:00 1921.168.1283.75 \nabernard 2022-05-12 23:38:46 19245.168.2345.49 \ncjackson 2022-05-12 19:36:42 192.168.247.153 \njclark 2022-05-10 10:48:02 192.168.174.117 \nalevitsk 2022-05-08 112:09:10 192.16874.1390.176 \njrafeal 2022-05-10 22:40:01 192.168.148.115 \nyappiah 2022-05-12 10:37:22 192.168.103.10654 \ndaquino 2022-05-08 7:02:35 192.168.168.144'
# display the contents of log_file
print(log_file)
# Out:
# eraab 2022-05-10 6:03:41 192.168.152.148
# iuduike 2022-05-09 6:46:40 192.168.22.115
# smartell 2022-05-09 19:30:32 192.168.190.178
# arutley 2022-05-12 17:00:59 1923.1689.3.24
# rjensen 2022-05-11 0:59:26 192.168.213.128
# aestrada 2022-05-09 19:28:12 1924.1680.27.57
# asundra 2022-05-11 18:38:07 192.168.96.200
# dkot 2022-05-12 10:52:00 1921.168.1283.75
# abernard 2022-05-12 23:38:46 19245.168.2345.49
# cjackson 2022-05-12 19:36:42 192.168.247.153
# jclark 2022-05-10 10:48:02 192.168.174.117
# alevitsk 2022-05-08 112:09:10 192.16874.1390.176
# jrafeal 2022-05-10 22:40:01 192.168.148.115
# yappiah 2022-05-12 10:37:22 192.168.103.10654
# daquino 2022-05-08 7:02:35 192.168.168.144

# %%
# open read and split a text file
with open('login_attempts.txt', 'r') as file:
  file_text = file.read()
print(file_text.split())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4651/2712368612.py in <cell line: 0>()
#       1 # open read and split a text file
# ----> 2 with open('login_attempts.txt', 'r') as file:
#       3   file_text = file.read()
#       4 print(file_text.split())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'login_attempts.txt'

# %%
# assign 'import_file' to the name of the text file that contains the security log file
import_file ='login.txt'
# assign missing_entry to  a log that was not recorded in the file
missing_entry = 'jrafael,192.168.243.140,4:56:27,2022-05-09'
# use opne to import security log file and store it as a string
# pass in 'a' as second parameter to indicate the field being opened
with open(import_file, 'a')
  #use .write() to append the missing_entry to the log file
  file.write(missing_entry)
# first line of the with statement
# use open() to import security log
with open(import_file, 'r') as file:
  # use .read() to read the imported file and store the result in a variable named text
  text = file.read()
# display the contents of text split into seperate lines
print(text)
